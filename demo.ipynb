# %%
#encoding:unicode
from fasterrcnn import faster_rcnn
from dataset import dataset
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
Dir = '../data/VOC-kd'
data = dataset(Dir,type='train')
getT = data.gen_batch()
Vdata = dataset(Dir,type='val')
getV = Vdata.gen_batch()

# %% [markdown]
# a=next(getT)[0]

# %% [markdown]
# a[4]

# %%
RCNN = faster_rcnn()

# %%
RCNN.build_model(modeltype='all',lr=0.001,momentum=0.5,f_trainable=True)
# Out:
# WARNING:tensorflow:From D:\software\anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# RCNN.model.load_weights('./modelWeight/model_25-0.6963.hdf5')

# %% [markdown]
# rlm,rlb,p,s = RCNN.model.predict([img,bboxCWH,anchros,rpnm,rpnb],1)
# p=p[0]
# s=s[0]

# %% [markdown]
# rlm

# %% [markdown]
# np.sum(np.equal(rlm,1))

# %% [markdown]
# plt.figure(figsize=(15,15))
# img = cv2.resize(img[0],(s[1],s[0]))
# plt.imshow(img)
# Axs = plt.gca()#get current Axs
# '''
# for i in range(p.shape[0]):
#     box = p[i]
#     rec = patches.Rectangle((box[0],box[1]),box[2]-box[0],box[3]-box[1],edgecolor = 'r',facecolor='none')
#     Axs.add_patch(rec)
# for i in range(bboxCWH.shape[1]):
#     box = bboxCWH[0][i]
#     rec = patches.Rectangle((box[0]-box[2]/2,box[1]-box[3]/2),box[2],box[3],edgecolor = 'b',facecolor='none')
#     Axs.add_patch(rec)
#     '''

# %%
RCNN.train(getT,getV,int(len(data.TrainList)/20),200,initial_epoch=0)
'''int(len(data.TrainList)/20)'''
# Out:
# WARNING:tensorflow:From D:\software\anaconda\lib\site-packages\tensorflow\python\ops\array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From D:\software\anaconda\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# D:\software\anaconda\lib\site-packages\tensorflow\python\ops\gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/200
# 58/58 [==============================] - 245s 4s/step - loss: 2.7439 - r_c: 0.1729 - r_delte: 0.1192 - c_c: 2.0097 - c_delte: 0.4421
#
# ...

# %%
a = tf.zeros(4,dtype=tf.int32)

# %%
sess = tf.Session()
sess.run(a)
# Out:
# array([0, 0, 0, 0])
